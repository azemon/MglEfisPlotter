# %% [markdown]
# # Oil Pressure During Flights 7 September 2019

# %%
from mgl_efis_plotter import *
# import pandas as pd

# %%
Config.rolling_window = 1
flights = create_flights('IEFIS.REC', Config)

# %%
for i in range(0, len(flights)): print(i, ':', flights[i])
# Out:
# 0 : Flight at 2019-06-21 10:20:36 to 2019-06-21 10:28:29,   352 messages
# 1 : Flight at 2019-06-21 10:28:30 to 2019-06-21 10:36:14,   2,217 messages
# 2 : Flight at 2019-06-21 11:26:42 to 2019-06-21 15:31:43,   69,550 messages
# 3 : Flight at 2019-06-21 16:27:46 to 2019-06-21 18:33:55,   35,600 messages
# 4 : Flight at 2019-06-22 07:48:46 to 2019-06-22 08:55:08,   18,862 messages
# 5 : Flight at 2019-06-22 09:56:14 to 2019-06-22 11:07:58,   20,479 messages
# 6 : Flight at 2019-06-22 13:17:35 to 2019-06-22 14:12:35,   15,642 messages
# 7 : Flight at 2019-06-27 18:09:52 to 2019-06-27 19:02:44,   13,054 messages
# 8 : Flight at 2019-06-30 07:12:15 to 2019-06-30 09:52:08,   45,704 messages
# 9 : Flight at 2019-06-30 14:29:19 to 2019-06-30 14:43:54,   4,180 messages
# 10 : Flight at 2019-06-30 15:16:21 to 2019-06-30 16:21:42,   18,685 messages
# 11 : Flight at 2019-06-30 18:39:33 to 2019-06-30 20:35:35,   32,957 messages
# ...

# %% [markdown]
# ## Overview

# %% [markdown]
# ## Oil Pressure Limits
# * 95 PSI maximum
# * 55 PSI (25 idling) minimum

# %% [markdown]
# ## Flight 1

# %%
p = Plot(flights[48])
p.plot2(['oilPressure1', 'oilTemperature1', 'rpm'], xlim=(0, 5)).show()
p.plot2(['oilPressure1', 'oilTemperature1', 'rpm'], xlim=(42, 48)).show()

# %% [markdown]
# # Flight 2

# %%
p = Plot(flights[49])
p.plot2(['oilPressure1', 'oilTemperature1', 'rpm'], xlim=(0, 5)).show()
p.plot2(['oilPressure1', 'oilTemperature1', 'rpm'], xlim=(55, 60)).show()
