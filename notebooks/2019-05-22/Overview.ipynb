# %% [markdown]
# # Flight 22 May 2019

# %%
from mgl_efis_plotter import *
import pandas as pd

# %%
flights = create_flights('IEFIS.REC', Config)
for i in range(0, len(flights)):
    print(i, flights[i])
# Out:
# 0 Flight at 2019-05-12 11:47:58 to 2019-05-12 12:07:22,   3,100 messages
# 1 Flight at 2019-05-12 12:07:23 to 2019-05-12 12:29:11,   6,276 messages
# 2 Flight at 2019-05-12 16:47:23 to 2019-05-12 17:28:25,   10,986 messages
# 3 Flight at 2019-05-22 17:58:57 to 2019-05-22 19:14:20,   21,747 messages
# 4 Flight at 2019-05-12 11:47:58 to 2019-05-12 11:47:58,   6 messages

# %% [markdown]
# ## Overview

# %%
p = Plot(flights[3])
p.plot2(['asi', 'oat', 'densityAltitude']).show()

# %%
p.plot2(['rpm', 'oilTemperature1', 'oilPressure1']).show()

# %%
p.plot2(['rpm', 'manifoldPressure', 'fuelFlow']).show()

# %% [markdown]
# ## Rate of Climb

# %%
# Config.rolling_window = 4
xlim = (20, 46)
ylim = (60, 105)
p.plot2(['asi', 'vsi'], xlim=xlim, ylim=ylim).show()
