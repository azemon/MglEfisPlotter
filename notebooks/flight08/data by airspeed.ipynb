# %% [markdown]
# # Data by Airspeed, Summarized for All Flights

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.append('../..')
from MglEfisPlotter import *

# %%
plt.rcParams['figure.figsize'] = (14, 10)

# %% [markdown]
# Load the flights from the file exported from the MGL iEFIS.

# %%
datafile = 'IEFISBB.DAT'

flights = createFlights(datafile)
for i in range(0, len(flights)):
    print(i, ':', flights[i])
# Out:
# 0 : Flight at 2019-03-21 14:52:20 to 2019-03-21 15:12:08,  5173 messages, timestamps 485,158,162 to 485,159,687
# 1 : Flight at 2019-03-23 12:51:18 to 2019-03-23 12:58:31,  1762 messages, timestamps 485,412,048 to 485,412,509
# 2 : Flight at 2019-03-23 13:56:41 to 2019-03-23 14:34:28,  9687 messages, timestamps 485,416,487 to 485,419,162
# 3 : Flight at 2019-03-27 16:21:26 to 2019-03-27 16:35:21,  3584 messages, timestamps 485,950,808 to 485,951,699
# 4 : Flight at 2019-03-27 16:52:31 to 2019-03-27 17:08:44,  4154 messages, timestamps 485,952,797 to 485,954,090
# 5 : Flight at 2019-03-27 17:19:47 to 2019-03-27 17:40:50,  5428 messages, timestamps 485,954,797 to 485,956,144
# 6 : Flight at 2019-03-27 17:59:52 to 2019-03-27 18:22:07,  5743 messages, timestamps 485,957,362 to 485,959,045

# %% [markdown]
# ## ASI vs CHT

# %%
for i in range(3, 7):
    p = Plot(flights[i])
    p.plot2(['asi', 'cht'])
    p.show()

# %% [markdown]
# ## ASI vs Oil Temperature & Pressure

# %%
for i in range(3, 7):
    p = Plot(flights[i])
    p.plot2(['asi', 'oilTemperature1', 'oilPressure1'])
    p.show()

# %% [markdown]
# ## ASI vs Pitch Angle

# %%
for i in range(3, 7):
    p = Plot(flights[i])
    p.plot2(['asi', 'pitchAngle'])
    p.show()
