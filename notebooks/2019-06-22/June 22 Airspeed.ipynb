# %% [markdown]
# # Airspeed 22 June 2019

# %%
from mgl_efis_plotter import *
import pandas as pd

# %%
flights = create_flights('IEFIS.REC', Config)
for i in range(0, len(flights)):
    print(i, flights[i])
# Out:
# 0 Flight at 2019-05-02 09:06:33 to 2019-05-02 09:17:34,   3,195 messages
# 1 Flight at 2019-05-12 11:47:58 to 2019-05-12 12:07:21,   3,088 messages
# 2 Flight at 2019-05-12 12:07:23 to 2019-05-12 12:29:12,   6,223 messages
# 3 Flight at 2019-05-12 16:47:24 to 2019-05-12 17:28:24,   10,950 messages
# 4 Flight at 2019-05-14 07:56:38 to 2019-05-14 08:48:51,   14,863 messages
# 5 Flight at 2019-05-16 16:32:37 to 2019-05-16 17:40:15,   18,930 messages
# 6 Flight at 2019-05-22 17:58:57 to 2019-05-22 19:14:19,   21,417 messages
# 7 Flight at 2019-05-24 11:08:44 to 2019-05-24 11:44:13,   7,623 messages
# 8 Flight at 2019-05-26 17:57:27 to 2019-05-26 19:12:58,   20,779 messages
# 9 Flight at 2019-05-27 09:25:32 to 2019-05-27 11:51:41,   41,531 messages
# 10 Flight at 2019-05-27 12:56:43 to 2019-05-27 13:32:50,   10,266 messages
# 11 Flight at 2019-05-28 12:40:26 to 2019-05-28 13:10:21,   8,568 messages
# 12 Flight at 2019-06-02 08:30:18 to 2019-06-02 09:17:20,   13,378 messages
# 13 Flight at 2019-06-02 09:50:44 to 2019-06-02 10:19:54,   8,033 messages
# 14 Flight at 2019-06-02 12:32:22 to 2019-06-02 13:23:18,   14,585 messages
# 15 Flight at 2019-06-07 13:48:55 to 2019-06-07 13:54:21,   1,544 messages
# 16 Flight at 2019-06-09 08:36:32 to 2019-06-09 08:45:05,   2,440 messages
# 17 Flight at 2019-06-09 09:44:35 to 2019-06-09 10:05:14,   5,895 messages
# 18 Flight at 2019-06-09 18:12:46 to 2019-06-09 18:27:57,   4,341 messages
# 19 Flight at 2019-06-09 18:41:37 to 2019-06-09 18:41:37,   2,898 messages
# 20 Flight at 2019-06-11 13:17:11 to 2019-06-11 13:22:30,   1,485 messages
# 21 Flight at 2019-06-11 13:49:34 to 2019-06-11 13:51:04,   437 messages
# 22 Flight at 2019-06-11 14:33:37 to 2019-06-11 14:34:56,   360 messages
# 23 Flight at 2019-06-12 07:12:18 to 2019-06-12 08:25:18,   20,780 messages
# 24 Flight at 2019-06-12 09:17:36 to 2019-06-12 11:35:38,   37,602 messages
# 25 Flight at 2019-06-12 11:35:40 to 2019-06-12 12:00:09,   6,978 messages
# 26 Flight at 2019-06-12 13:50:05 to 2019-06-12 17:42:36,   65,984 messages
# 27 Flight at 2019-06-21 10:20:34 to 2019-06-21 10:28:29,   369 messages
# 28 Flight at 2019-06-21 10:28:31 to 2019-06-21 10:36:13,   2,198 messages
# 29 Flight at 2019-06-21 11:26:42 to 2019-06-21 15:31:41,   70,477 messages
# 30 Flight at 2019-06-21 16:27:46 to 2019-06-21 18:33:54,   36,475 messages
# 31 Flight at 2019-06-22 07:48:46 to 2019-06-22 08:55:08,   19,272 messages
# 32 Flight at 2019-06-22 09:56:14 to 2019-06-22 11:07:57,   20,775 messages
# 33 Flight at 2019-06-22 13:17:35 to 2019-06-22 14:12:34,   15,778 messages
# 34 Flight at 2019-05-02 09:06:31 to 2019-05-02 09:06:31,   7 messages

# %% [markdown]
# ## Overview

# %%
p = Plot(flights[33])
p.plot2(['asi', 'pAltitude', 'tas']).show()

# %%
p.plot2(['rpm', 'manifoldPressure', 'fuelFlow']).show()

# %% [markdown]
# ## Airspeed

# %%
xlim = (25, 35)
p.plot2(['asi', 'pAltitude', 'tas'], xlim=xlim).show()

# %%
asi_data = p.flight.list_data('asi')
asi = pd.DataFrame(asi_data, index=asi_data['minutes'], columns=['asi'])

tas_data = p.flight.list_data('tas')
tas = pd.DataFrame(tas_data, index=tas_data['minutes'], columns=['tas'])

ff_data = p.flight.list_data('fuelFlow')
ff = pd.DataFrame(ff_data, index=ff_data['minutes'], columns=['fuelFlow'])

# %%
print('Average ASI at 4,500 feet =', float(asi.loc[25:35].mean()), 'knots')
print('Average TAS at 4,500 feet =', float(tas.loc[25:35].mean()), 'knots')
print('Average fuel flow at 4,500 feet =', float(ff.loc[25:35].mean()), 'GPH')
# Out:
# Average ASI at 4,500 feet = 122.72103602453285 knots
# Average TAS at 4,500 feet = 137.28428779805833 knots
# Average fuel flow at 4,500 feet = 9.548601047650719 GPH
