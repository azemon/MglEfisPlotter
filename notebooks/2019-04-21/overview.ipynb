# %% [markdown]
# # Overview April 21, 2019

# %%
from mgl_efis_plotter import *

# %%
flights = create_flights('IEFISBB.DAT', Config)
for i in range(0, len(flights)):
    print(i, ':', flights[i])
# Out:
# 0 : Flight at 2019-04-06 13:32:22 to 2019-04-06 13:53:19,   5,363 messages
# 1 : Flight at 2019-04-21 12:17:25 to 2019-04-21 14:16:02,   29,800 messages

# %%
f = flights[1]
p = Plot(f)

# %% [markdown]
# ## Altitude & Heading with Autopilot

# %%
p.plot2(['pAltitude', 'headingMag']).show()

# %%
p.plot2(['asi', 'densityAltitude']).show()

# %% [markdown]
# ## Heading During Turn

# %%
p.plot2(['headingMag', 'turnRate'], xlim=(33, 38)).show()

# %%
p.plot2(['headingMag', 'turnRate'], ['Heading', 'Turn Rate'], xlim=(80, 84)).show()

# %% [markdown]
# ## Altitude Change
#
# The blip from minutes 50 to 53 is me taking manual control to descend and turn to avoid traffic.

# %%
p.plot2(['pAltitude', 'vsi'], xlim=(27, 60)).show()

# %%
p.plot2(['pAltitude', 'vsi'], xlim=(75, 105)).show()
