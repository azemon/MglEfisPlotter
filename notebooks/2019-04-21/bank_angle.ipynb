# %% [markdown]
# # Bank Angle April 21, 2019

# %%
from mgl_efis_plotter import *
flights = create_flights('IEFISBB.DAT', Config)
f = flights[1]
p = Plot(f)

# %%
p.plot2(['bankAngle', 'turnRate'], ['Bank Angle', 'Turn Rate']).save('bank_angle.png')

# %%
p.plot2(['slip']).save('slip.png')
