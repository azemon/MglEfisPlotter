# %% [markdown]
# # Blog Graphs

# %%
from mgl_efis_plotter import *

# %%
flights = create_flights('IEFISBB.DAT', Config)
f = flights[1]
p = Plot(f)

# %%
p.plot2(['pAltitude', 'asi'], ['Altitude (feet)', 'Airspeed (knots)']).save('altitude-airspeed.png')
p.plot2(['pAltitude', 'vsi'], ['Altitude (feet)', 'Vertical Speed (ft/min)']).save('altitude-vertical-speed.png')
