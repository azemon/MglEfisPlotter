# %% [markdown]
# # Fuel Flow April 21, 2019

# %%
from mgl_efis_plotter import *
flights = create_flights('IEFISBB.DAT', Config)
f = flights[1]
p = Plot(f)

# %%
f.list_attributes()
# Out:
# agl
# ambientPressure
# aoa
# asi
# auxTemperature1
# auxTemperature2
# auxTemperature3
# auxTemperature4
# bAltitude
# bankAngle
# baro
# cht
# coolantTemperature
# date
# date_time
# densityAltitude
# downVelocity
# eastVelocity
# egt
# engineNumber
# ftHour
# ftMin
# fuelFlow
# fuelPressure
# gForce
# gps
# gpsAltitude
# gpsCapability
# groundSpeed
# headingMag
# horizontalAccuracy
# hour
# humidity
# inletTemperature
# latitude
# local
# longitude
# manifoldPressure
# minute
# month
# northVelocity
# numberOfCht
# numberOfEgt
# oat
# oilPressure1
# oilTemperature1
# oilTemperature2
# pAltitude
# pitchAngle
# raimHError
# raimVError
# rpm
# satsTracked
# satsVisible
# second
# sensorFlags
# slip
# systemFlags
# tas
# trueTrack
# turnRate
# variation
# verticalAccuracy
# vsi
# yawAngle
# year

# %%
p.plot2(['fuelFlow', 'densityAltitude']).show()
