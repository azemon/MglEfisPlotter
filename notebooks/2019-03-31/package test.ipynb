# %% [markdown]
# # Package Test

# %%
from mgl_efis_plotter import *

config = Config()

flights = create_flights('IEFIS.REC', config)

for i in range(0, len(flights)):
    print(i, flights[i])

p = Plot(flights[1])

# %%
p.plot2(['pAltitude', 'densityAltitude', 'oat'], ['Altitude', 'Density Altitude', 'Outside Air Temp (C)']).show()
