# %% [markdown]
# # Oil Pressure During Flight 31 August 2019

# %%
from mgl_efis_plotter import *
import pandas as pd

# %%
flights = create_flights('IEFIS.REC', Config)

# %% [markdown]
# ## Overview

# %%
p = Plot(flights[45])

# %%
p.plot2(['oilPressure1', 'oilTemperature1', 'rpm']).show()

# %% [markdown]
# ## Oil Pressure Limits
# * 95 PSI maximum
# * 55 PSI (25 idling) minimum

# %% [markdown]
# ## Oil Pressure During Initial Climb

# %%
xlim = (0, 5)
p.plot2(['oilPressure1', 'oilTemperature1', 'rpm'], xlim=xlim, ylim=(80, 110)).show()

# %% [markdown]
# ## Oil Pressure During Cruise

# %%
xlim = (10, 25)
p.plot2(['oilPressure1', 'oilTemperature1', 'rpm'], xlim=xlim, ylim=(70, 80)).show()
