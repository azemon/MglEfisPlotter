# %% [markdown]
# # Flight 06 N2468Z
#
# BD-4C N2468Z on 19 March 2019 at St. Charles County Smartt Airport (KSET).
#
# ## Setup

# %%
# %matplotlib inline

import sys
sys.path.append('../..')
from MglEfisPlotter import *

# %% [markdown]
# Load the flights from the file exported from the MGL iEFIS.

# %%
datafile = '../../data/IEFISBB.DAT.02'
minTimestamp = 0
maxTimestamp = 600000000

flights = createFlights(datafile, minTimestamp, maxTimestamp)
for i in range(0, len(flights)):
    print(i, ':', flights[i])

p = Plot(flights[6])
print(p.flight)
# Out:
# 0 : Flight at 2019-03-19 17:03:36-17:10:15,  1709 messages, 484905186-484905614
# 1 : Flight at 2019-02-03 11:10:08-11:10:10,    26 messages, 478589574-478589577
# 2 : Flight at 2019-02-13 14:14:20-14:29:57,  3969 messages, 479912850-479913848
# 3 : Flight at 2019-03-18 18:07:28-18:08:43,   328 messages, 484778459-484778537
# 4 : Flight at 2019-03-18 17:09:11-17:09:29,    86 messages, 484774471-484774490
# 5 : Flight at 2019-03-19 13:18:49-14:02:02,  9954 messages, 484889570-484892801
# 6 : Flight at 2019-03-19 15:46:45-17:03:33, 19433 messages, 484899755-484905184
# Flight at 2019-03-19 15:46:45-17:03:33, 19433 messages, 484899755-484905184

# %% [markdown]
# ## Graphs

# %%
p.plot2(['asi', 'groundSpeed'])
p.show()

# %%
p.plot2(['asi', 'oilPressure1', 'oilTemperature1'])
p.show()
