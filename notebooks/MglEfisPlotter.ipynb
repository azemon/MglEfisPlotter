# %% [markdown]
# # MGL EFIS Plotter

# %% [markdown]
# Start by importing the MglEfisPlotter code.

# %%
# %matplotlib inline

import sys
sys.path.append('..')
from MglEfisPlotter import *

# %% [markdown]
# Load some flights from the sample `IEFISBB.DAT` file.

# %%
datafile = '../data/IEFISBB.DAT'
minTimestamp = 429600874
maxTimestamp = 1000000000

flights = createFlights(datafile, minTimestamp, maxTimestamp)

# %% [markdown]
# ## Print the Flights
#
# For each flight, we can see the takeoff and landing times, the number of EFIS messages which were recorded, and the timestamps.

# %%
def printFlights(flights):
    for i in range(0, len(flights)):
        print(i, '--', flights[i])

printFlights(flights)
# Out:
# 0 -- Flight at 2018-06-13 19:01:44-19:06:13,   926 messages, 429600874-429601163
# 1 -- Flight at 2019-02-03 10:11:30-10:20:23,   514 messages, 478585564-478586132
# 2 -- Flight at 2019-02-03 10:55:25-10:55:58,   153 messages, 478588375-478588408
# 3 -- Flight at 2019-02-03 11:09:38-11:10:13,   128 messages, 478589541-478589579
# 4 -- Flight at 2019-02-13 14:14:21-14:29:57,  3903 messages, 479912852-479913848

# %% [markdown]
# ## Create a Plot Object
#
# The Plot object handles all of the work. It knows how to find good stuff inside the MGL EFIS messages and how to generate graphs. The subscript `[-1]` is shorthand for the last flight.

# %%
p = Plot(flights[-1])
print('p is the last flight:', p.flight)
# Out:
# p is the last flight: Flight at 2019-02-13 14:14:21-14:29:57,  3903 messages, 479912852-479913848

# %% [markdown]
# ## First Plot
#
# Now let's plot airspeed. We do that by plotting the 'asi' attribute, the airspeed indicator.

# %%
p.plot('asi')
p.show()

# %% [markdown]
# ## Second Plot
#
# We can get fancier, plotting two lines. Here is a plot of oil pressure and oil temperature.

# %%
p.plot2(['oilPressure1', 'oilTemperature1'])
p.show()
