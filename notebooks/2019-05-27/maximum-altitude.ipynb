# %% [markdown]
# # Maximum Altitude Test 27 May 2019

# %%
from mgl_efis_plotter import *
import pandas as pd

# %%
flights = create_flights('IEFIS.REC', Config)
for i in range(0, len(flights)):
    print(i, flights[i])
p = Plot(flights[0])
# Out:
# 0 Flight at 2019-05-27 09:25:34 to 2019-05-27 11:51:39,   42,446 messages
# 1 Flight at 2019-05-27 12:56:43 to 2019-05-27 13:32:51,   10,508 messages
# 2 Flight at 2019-05-27 09:25:32 to 2019-05-27 09:25:32,   7 messages

# %% [markdown]
# ## Maximum Altitude

# %%
xlim = (0, 70)
p.plot2(['densityAltitude', 'asi', 'tas'], xlim=xlim).show()

# %%
p.plot2(['pAltitude', 'densityAltitude'], xlim=xlim).show()
p.plot2(['pAltitude', 'densityAltitude'], xlim=(50, 60), ylim=(13000, 14000)).show()
p.plot2(['densityAltitude', 'pAltitude'], xlim=(50, 60), ylim=(15500, 16000)).show()

# %%
p.plot2(['pAltitude', 'baro', 'oat'], xlim=xlim).show()
