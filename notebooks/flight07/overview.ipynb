# %% [markdown]
# # Flight 08 N2468Z
#
# Tests of BD-4C N2468Z on 23 March 2019 at St. Charles County Smartt Airport (KSET).
#
# ## Setup

# %%
# %matplotlib inline

import sys
sys.path.append('../..')
from MglEfisPlotter import *

# %% [markdown]
# Load the flights from the file exported from the MGL iEFIS.

# %%
datafile = 'IEFISBB.DAT'

flights = createFlights(datafile)
for i in range(0, len(flights)):
    print(i, ':', flights[i])

p = Plot(flights[-1])
print(p.flight)
# Out:
# 0 : Flight at 2019-03-20 15:41:18 to 2019-03-20 15:52:06,  2811 messages, timestamps 485,030,479 to 485,031,171
# 1 : Flight at 2019-03-20 15:41:18 to 2019-03-21 15:12:08, 21232 messages, timestamps 485,153,850 to 485,159,687
# 2 : Flight at 2019-03-23 12:51:17 to 2019-03-23 12:58:31,  1773 messages, timestamps 485,412,047 to 485,412,509
# 3 : Flight at 2019-03-23 13:56:40 to 2019-03-23 14:34:28,  9657 messages, timestamps 485,416,486 to 485,419,162
# Flight at 2019-03-23 13:56:40 to 2019-03-23 14:34:28,  9657 messages, timestamps 485,416,486 to 485,419,162

# %% [markdown]
# ## Graphs

# %%
p.plot2(['local', 'oat', 'pAltitude', 'densityAltitude'])
p.show()

p.plot2(['asi', 'tas'])
p.show()

# %%
p.plot2(['asi', 'groundSpeed'])
p.show()

# %%
p.plot2(['pAltitude', 'vsi'])
p.show()

# %%
p.plot('cht')
p.show()

# %%
p.plot('egt')
p.show()

# %%
f = flights[3]
p.plot2(['fuelFlow', 'rpm', 'manifoldPressure'])
p.show()
