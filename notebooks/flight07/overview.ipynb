# %% [markdown]
# # Flight 07 N2468Z
#
# Stall tests of BD-4C N2468Z on 21 March 2019 at St. Charles County Smartt Airport (KSET).
#
# ## Setup

# %%
# %matplotlib inline

import sys
sys.path.append('../..')
from MglEfisPlotter import *

# %% [markdown]
# Load the flights from the file exported from the MGL iEFIS.

# %%
datafile = '../../data/IEFISBB.DAT.04'
minTimestamp = 0
maxTimestamp = 600000000

flights = createFlights(datafile, minTimestamp, maxTimestamp)
for i in range(0, len(flights)):
    print(i, ':', flights[i])

p = Plot(flights[3])
print(p.flight)
# Out:
# 0 : Flight at 2019-03-19 17:03:36-17:10:15,  1711 messages, 484905186-484905614
# 1 : Flight at 2019-03-20 15:10:04-15:15:09,  1280 messages, 485028482-485028806
# 2 : Flight at 2019-03-20 15:31:45-15:52:06,  5011 messages, 485029867-485031171
# 3 : Flight at None-15:12:06, 21226 messages, 485153850-485159685
# 4 : Flight at 2019-03-19 16:38:54-17:03:31,  6293 messages, 484903348-484905181
# Flight at None-15:12:06, 21226 messages, 485153850-485159685

# %% [markdown]
# ## Graphs

# %%
p.plot2(['asi', 'groundSpeed'])
p.show()

# %%
p.plot2(['pAltitude', 'vsi'])
p.show()

# %%
p.plot('cht')
p.show()

# %%
p.plot('egt')
p.show()

# %%
f = flights[3]
#f.listAttributes()
p.plot2(['fuelFlow', 'rpm', 'manifoldPressure'])
p.show()
